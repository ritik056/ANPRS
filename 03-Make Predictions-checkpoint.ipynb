# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# %%
#load model
model=tf.keras.models.load_model('./models/object_detection.h5')
print("model loaded sucessfully")
# Out:
# model loaded sucessfully

# %%
path = r"C:\Users\hrish\OneDrive\Desktop\OIP (3).jpg"
image = load_img(path)
image = np.array(image,dtype=np.uint8)
image1 = load_img(path,target_size=(224,224,3))
image_arr_224 = img_to_array(image1)/255.0

# %%
h,w,d=image.shape
print("height = ",h)
print("width = ",w)
print(d)
# Out:
# height =  234
# width =  312
# 3

# %%
plt.imshow(image)
plt.show()

# %%
image_arr_224.shape
# Out:
# (224, 224, 3)

# %%
test_arr = image_arr_224.reshape(1,224,224,3)
test_arr.shape
# Out:
# (1, 224, 224, 3)

# %%
#make predictions
coords=model.predict(test_arr)
coords
# Out:
# 1/1 [==============================] - 0s 109ms/step
# array([[0.2936806 , 0.68291277, 0.4333944 , 0.572527  ]], dtype=float32)

# %%
denorm = np.array([w,w,h,h])
coords = coords*denorm
coords
# Out:
# array([[ 91.62834978, 213.06878328, 101.41429013, 133.97131598]])

# %%
coords = coords.astype(np.int)
coords
# Out:
# C:\Users\hrish\AppData\Local\Temp\ipykernel_9320\3703791417.py:1: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   coords = coords.astype(np.int)
# array([[ 91, 213, 101, 133]])

# %%
xmin, xmax,ymin,ymax = coords[0]
plt1 = (xmin,ymin)
plt2 = (xmax,ymax)
print(plt1,plt2)
cv2.rectangle(image,plt1,plt2,(0,255,0),3)

plt.figure(figsize=(10,8))
plt.imshow(image)
plt.show()
# Out:
# (91, 101) (213, 133)

# %%
xmin,xmax,ymin,ymax=coords[0]

# %%
img = np.array(load_img(path))
xmin,xmax,ymin,ymax=coords[0]
roi=img[ymin:ymax,xmin:xmax]

# %%
plt.imshow(roi)
plt.show()

# %%
import easyocr

# %%
import pytesseract

# %%
pytesseract.pytesseract.tesseract_cmd=r"C:\\Program Files\\Tesseract-OCR\\tesseract.exe"

# %%
text=pytesseract.image_to_string(roi)
print(text)
# Out:
# TKA G2MP 9657

# %%
read=easyocr.Reader(['en'])
result=read.readtext(roi)
result
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# [([[18, 8], [122, 8], [122, 32], [18, 32]],
#   'KA G2HP 9657',
#   0.5579811163507108)]
